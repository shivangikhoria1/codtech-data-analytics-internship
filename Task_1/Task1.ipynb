# %%
# !pip install kaggle

# %% [markdown]
# # Big Data Analysis Using PySpark
# ### Internship Task 1 – CODTECH
#
# **Name:** Your Name
# **Role:** Data Analytics Intern
# **Tool Used:** PySpark

# %% [markdown]
# ## Objective
#
# The objective of this task is to perform scalable data analysis using PySpark on a structured e-commerce dataset.
# This task demonstrates the ability to process large datasets and derive meaningful business insights using distributed computing.

# %% [markdown]
# ## Dataset Description
#
# The dataset contains 30,600 records of Indian e-commerce transactions.
#
# Main features include:
# - Order ID and Order Date
# - State and Zone
# - Product Category
# - Brand Type (Mass / Premium)
# - Customer Gender and Age
# - Base Price, Discount, Final Price
# - Units Sold and Revenue
# - Sales Event (Festival / Normal)
# - Competition Intensity
# - Inventory Pressure

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-eee89f02-d40b-41eb-92a3-498b1a6ca977" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eee89f02-d40b-41eb-92a3-498b1a6ca977">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Import SparkSession
from pyspark.sql import SparkSession

# Create Spark session
spark = SparkSession.builder \
    .appName("Indian Ecommerce Big Data Analysis") \
    .getOrCreate()

print("Spark Session Created Successfully")
# Out:
# Spark Session Created Successfully

# %% [markdown]
# ## Data Loading
#
# The dataset is loaded into a PySpark DataFrame for scalable processing.

# %%
# Load CSV file into Spark DataFrame
df = spark.read.csv("Indian_Ecommerce(in).csv", header=True, inferSchema=True)

print("Total Records:", df.count())
# Out:
# Total Records: 30600

# %% [markdown]
# ## Schema Overview
#
# Inspecting the structure and data types of the dataset.

# %%
df.printSchema()
df.show(5)
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- order_date: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- zone: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- brand_type: string (nullable = true)
#  |-- customer_gender: string (nullable = true)
#  |-- customer_age: integer (nullable = true)
#  |-- base_price: double (nullable = true)
#  |-- discount_percent: double (nullable = true)
#  |-- final_price: double (nullable = true)
#  |-- units_sold: integer (nullable = true)
#  |-- revenue: double (nullable = true)
#  |-- sales_event: string (nullable = true)
#  |-- competition_intensity: string (nullable = true)
#  |-- inventory_pressure: string (nullable = true)
#
# +----------+----------+--------------+-------+------------------+----------+---------------+------------+----------+----------------+-----------+----------+---------+-----------+---------------------+------------------+
# ...

# %%
import os
os.listdir()
# Out:
# ['.config', 'Indian_Ecommerce(in).csv', 'sample_data']

# %%
# !pip install pyspark

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Indian Ecommerce Big Data Analysis") \
    .getOrCreate()

print("Spark Session Created Successfully")
# Out:
# Spark Session Created Successfully

# %%
import os
os.listdir()
# Out:
# ['.config', 'Indian_Ecommerce(in).csv', 'sample_data']

# %%
df = spark.read.csv("Indian_Ecommerce(in).csv", header=True, inferSchema=True)

df.printSchema()
print("Total Records:", df.count())
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- order_date: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- zone: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- brand_type: string (nullable = true)
#  |-- customer_gender: string (nullable = true)
#  |-- customer_age: integer (nullable = true)
#  |-- base_price: double (nullable = true)
#  |-- discount_percent: double (nullable = true)
#  |-- final_price: double (nullable = true)
#  |-- units_sold: integer (nullable = true)
#  |-- revenue: double (nullable = true)
#  |-- sales_event: string (nullable = true)
#  |-- competition_intensity: string (nullable = true)
#  |-- inventory_pressure: string (nullable = true)
#
# Total Records: 30600

# %%
df.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- order_date: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- zone: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- brand_type: string (nullable = true)
#  |-- customer_gender: string (nullable = true)
#  |-- customer_age: integer (nullable = true)
#  |-- base_price: double (nullable = true)
#  |-- discount_percent: double (nullable = true)
#  |-- final_price: double (nullable = true)
#  |-- units_sold: integer (nullable = true)
#  |-- revenue: double (nullable = true)
#  |-- sales_event: string (nullable = true)
#  |-- competition_intensity: string (nullable = true)
#  |-- inventory_pressure: string (nullable = true)

# %%
df.show(5)
# Out:
# +----------+----------+--------------+-------+------------------+----------+---------------+------------+----------+----------------+-----------+----------+---------+-----------+---------------------+------------------+
# |  order_id|order_date|         state|   zone|          category|brand_type|customer_gender|customer_age|base_price|discount_percent|final_price|units_sold|  revenue|sales_event|competition_intensity|inventory_pressure|
# +----------+----------+--------------+-------+------------------+----------+---------------+------------+----------+----------------+-----------+----------+---------+-----------+---------------------+------------------+
# |ORD0000001| 1/31/2023|   West Bengal|   East|           Fashion|      Mass|           Male|          28|   1810.89|            65.0|     633.81|        29| 18380.49|     Normal|               Medium|              High|
# ...

# %%
from pyspark.sql.functions import sum

df.select(sum("revenue")).show()
# Out:
# +--------------------+
# |        sum(revenue)|
# +--------------------+
# |2.1745103669900055E9|
# +--------------------+

# %%
df.groupBy("sales_event") \
  .sum("revenue") \
  .show()
# Out:
# +-----------+--------------------+
# |sales_event|        sum(revenue)|
# +-----------+--------------------+
# |   Festival| 7.606892495400027E8|
# |     Normal|1.4138211174499946E9|
# +-----------+--------------------+

# %%
df.groupBy("category") \
  .sum("revenue") \
  .orderBy("sum(revenue)", ascending=False) \
  .show()
# Out:
# +--------------------+--------------------+
# |            category|        sum(revenue)|
# +--------------------+--------------------+
# |   Premium Lifestyle|      6.4809691069E8|
# |         Electronics| 5.205174911400006E8|
# |    Sports & Fitness| 2.833666460400004E8|
# |       Home & Living|2.3667829913000074E8|
# |            Footwear|1.9576828262999964E8|
# |             Fashion|1.5787525019999993E8|
# |Beauty & Personal...|1.0162320439999971E8|
# |  Grocery Essentials|3.0584282760000054E7|
# +--------------------+--------------------+

# %%
df.groupBy("state") \
  .sum("revenue") \
  .orderBy("sum(revenue)", ascending=False) \
  .show()
# Out:
# +--------------+--------------------+
# |         state|        sum(revenue)|
# +--------------+--------------------+
# |     Delhi NCR|1.9569107363000003E8|
# |   Maharashtra|1.8944358546000004E8|
# |     Karnataka|1.8876721442000037E8|
# |        Kerala| 1.683533524499998E8|
# |       Gujarat|1.6821556560000008E8|
# |     Telangana| 1.669117726399997E8|
# |    Tamil Nadu|1.6540152774000007E8|
# |        Punjab|1.5866575261999977E8|
# |       Haryana|1.5723338196000013E8|
# |Madhya Pradesh|1.3122563678999998E8|
# | Uttar Pradesh|1.2492213223999994E8|
# |   West Bengal|1.2246277585999976E8|
# |        Odisha| 1.218676474700002E8|
# |  Chhattisgarh|1.1534894810999987E8|
# +--------------+--------------------+

# %%
df.groupBy("customer_gender")
  .sum("revenue") \
  .show()
# Out:
# +---------------+--------------------+
# |customer_gender|        sum(revenue)|
# +---------------+--------------------+
# |         Female|1.0884523070900016E9|
# |           Male| 1.086058059899995E9|
# +---------------+--------------------+

# %% [markdown]
# ## Total Revenue Analysis

# %%
from pyspark.sql.functions import sum

df.select(sum("revenue")).show()
# Out:
# +--------------------+
# |        sum(revenue)|
# +--------------------+
# |2.1745103669900055E9|
# +--------------------+

# %% [markdown]
# Conclusion
#
# This analysis was performed using PySpark on a dataset containing 30,600 records to demonstrate scalable big data processing.
#
# Key findings:
#
# Total revenue generated: ₹2.17 Billion.
#
# Premium Lifestyle category contributed the highest revenue.
#
# Delhi NCR emerged as the top-performing state.
#
# Revenue distribution between male and female customers is nearly equal.
#
# Festival events significantly boost revenue during promotional periods.
#
# Although the dataset size is moderate, the implementation using PySpark ensures scalability for handling millions of records efficiently in real-world scenarios.
